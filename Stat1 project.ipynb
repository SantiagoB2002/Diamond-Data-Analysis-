# %%
import pandas as pd
import numpy as np

data_df=pd.read_csv('Mispriced-Diamonds.csv')
data_df.head
# Out:
# <bound method NDFrame.head of        carat clarity  price
# 0       0.23     SI2    326
# 1       0.21     SI1    326
# 2       0.23     VS1    327
# 3       0.29     VS2    334
# 4       0.31     SI2    335
# ...      ...     ...    ...
# 53935   0.72     SI1   2757
# 53936   0.72     SI1   2757
# 53937   0.70     SI1   2757
# 53938   0.86     SI2   2757
# 53939   0.75     SI2   2757
#
# [53940 rows x 3 columns]>

# %%
x=data_df.drop(['price'],axis=1).values
y=data_df['price'].values

# %%
print(x)
# Out:
# [[0.23]
#  [0.21]
#  [0.23]
#  ...
#  [0.7 ]
#  [0.86]
#  [0.75]]

# %%
print(y)
# Out:
# [ 326  326  327 ... 2757 2757 2757]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
ml=LinearRegression()
ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=ml.predict(x_test)
print(y_pred)
# Out:
# [ 6267.81248226  7738.67450143  7041.95038709 ...  9441.77789205
#  14628.5018544  13622.12257813]

# %%
ml.predict([[ 0.23 ]])
# Out:
# array([-467.18728975])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8509771156910653

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
pred_y_df=pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred, 'Difference':y_test-y_pred})
pred_y_df[0:20]
# Out:
#     Actual value  Predicted value   Difference
# 0           4733      6267.812482 -1534.812482
# 1           6424      7738.674501 -1314.674501
# 2           5510      7041.950387 -1531.950387
# 3           8770      9364.364102  -594.364102
# 4           4493      4719.536673  -226.536673
# 5            918       229.536825   688.463175
# 6            789        74.709244   714.290756
# 7           2823      2474.536749   348.463251
# 8          18705     13312.467416  5392.532584
# 9            507       152.123034   354.876966
# 10          1880      2706.778120  -826.778120
# 11           935       926.260939     8.739061
# 12          1872      1777.812634    94.187366
# 13           956        74.709244   881.290756
# 14          3111      5571.088368 -2460.088368
# 15         16499     13312.467416  3186.532584
# 16           954       229.536825   724.463175
# 17          8342      9441.777892 -1099.777892
# 18          8711     17105.743150 -8394.743150
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
df= pd.read_csv('Mispriced-Diamonds_1.csv')
df.describe()
# Out:
#               carat         price
# count  53940.000000  53940.000000
# mean       0.797940   3932.799722
# std        0.474011   3989.439738
# min        0.200000    326.000000
# 25%        0.400000    950.000000
# 50%        0.700000   2401.000000
# 75%        1.040000   5324.250000
# max        5.010000  18823.000000

# %%
# %matplotlib
# Out:
# Using matplotlib backend: QtAgg

# %%
plt.hist(df['carat'], bins = 25, edgecolor='black')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.title('Carat vs. Price')
# Out:
# Text(0.5, 1.0, 'Carat vs. Price')

# %%
import numpy as np
import matplotlib.pyplot as plt  # To visualize
import pandas as pd  # To read data
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Mispriced-Diamonds_1.csv')  # load data set
X = data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()
